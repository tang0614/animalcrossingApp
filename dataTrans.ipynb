# %%
import pandas as pd
import numpy as np
import tqdm

# %%
animals = np.load('/Users/anna/Desktop/Animalcrossing/data/animals_data.npy',allow_pickle=True)

# %%
animals = list(animals)

# %%
df = pd.DataFrame(data=animals)

# %%
df= df.replace(r'\n','', regex=True)

# %%
df[['month','date']] = df['birth'].str.split(expand=True)

# %%
dic_time={
    "January":1,
    "Feburary":2,
    "March":3,
    "April":4,
    "May":5,
    "June":6,
    "July":7,
    "August":8,
    "September":9,
    "October":10,
    "November":11,
    "December":12,
}

# %%
def zodiac_sign(day, month): 
    # checks month and date within the valid range 
    # of a specified zodiac 
    if month == 'December': 
        return 'Sagittarius' if (day < 22) else 'Capricorn'

    elif month == 'January': 
        return 'Capricorn' if (day < 20) else 'Aquarius'

    elif month == 'February': 
        return 'Aquarius' if (day < 19) else 'Pisces'

    elif month == 'March': 
        return 'Pisces' if (day < 21) else 'Aries'

    elif month == 'April': 
        return 'Aries' if (day < 20) else 'Taurus'

    elif month == 'May': 
        return 'Taurus' if (day < 21) else 'Gemini'

    elif month == 'June': 
        return 'Gemini' if (day < 21) else 'Cancer'

    elif month == 'July': 
        return 'Cancer' if (day < 23) else 'Leo'

    elif month == 'August': 
        return 'Leo' if (day < 23) else 'Virgo'

    elif month == 'September': 
        return 'Virgo' if (day < 23) else 'Libra'

    elif month == 'October': 
        return 'Libra' if (day < 23) else 'Scorpio'

    elif month == 'November': 
        return 'scorpio' if (day < 22) else 'Sagittarius'

# %%
df.date = df.date.astype(int)

# %%
df['star'] = df.apply(lambda x: zodiac_sign(x['date'], x['month']), axis=1)

# %%
np.save(f'/Users/anna/Desktop/Animalcrossing/data/full_url.npy',full_url)

# %%
df = pd.read_csv('/Users/anna/Desktop/Animalcrossing/data/animals_df.csv')

# %%
starA = df['star']
starB = df['star']

index = pd.MultiIndex.from_product([starA, starB], names = ["starA", "starB"])

star_matrix = pd.DataFrame(index = index).reset_index()
star_list=[]
for i, j in star_matrix.groupby('starA'):
    if((i=='Aries')|(i=='Leo')|(i=='Sagittarius')):
        for m, n in j.groupby('starB'):
            if((m=='Cancer')|(m=='Scorpio')|(m=='Pisces')):
                
                n['score'] = 0
                star_list.append(n)
            elif( (m=='Aries')|(m=='Leo')|(m=='Sagittarius')):
                n['score'] = 3
                star_list.append(n)
            else:
                n['score'] = 2
                star_list.append(n)
                
    elif((i=='Taurus')|(i=='Virgo')|(i=='Capricorn')):
        for m, n in j.groupby('starB'):
            if((m=='Gemini')|(m=='Libra')|(m=='Aquarius')):
                n['score'] = 0
                star_list.append(n)
            elif((m=='Taurus')|(m=='Virgo')|(m=='Capricorn')):
                n['score'] = 3
                star_list.append(n)
            else:
                n['score'] = 2
                star_list.append(n)
                
    elif((i=='Gemini')|(i=='Libra')|(i=='Aquarius')):
        for m, n in j.groupby('starB'):
            if((m=='Taurus')|(m=='Virgo')|(m=='Capricorn')):
                n['score'] = 0
                star_list.append(n)
            elif((m=='Gemini')|(m=='Libra')|(m=='Aquarius')):
                n['score'] = 3
                star_list.append(n)
            else:
                n['score'] = 2
                star_list.append(n)
            
    elif((i=='Cancer')|(i=='Scorpio')|(i=='Pisces')):
        for m, n in j.groupby('starB'):
            if((m=='Aries')|(m=='Leo')|(m=='Sagittarius')):
                n['score'] = 0
                star_list.append(n)
            elif((m=='Cancer')|(m=='Scorpio')|(m=='Pisces')):
                n['score'] = 3
                star_list.append(n)
            else:
                n['score'] = 2
                star_list.append(n)
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:37: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
star_score = pd.concat(star_list,axis=0).reset_index(drop=True)

# %%
star_score=star_score.drop_duplicates(keep='first')

# %%
star_score.to_csv('/Users/anna/Desktop/Animalcrossing/data/star_score.csv')

# %%
persA = df['personality']
persB = df['personality']

index = pd.MultiIndex.from_product([persA, persB], names = ["persA", "persB"])

pers_matrix = pd.DataFrame(index = index).reset_index()

pers_list=[]
for i, j in pers_matrix.groupby('persA'):
    if(i=='Normal'):
        for m, n in j.groupby('persB'):
            if((m=='Snooty')|(m=='Smug')):
                
                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Jock')|(m=='Sisterly')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Cranky')|(m=='Normal')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)
                
    elif(i=='Lazy'):
        for m, n in j.groupby('persB'):
            if((m=='Lazy')|(m=='Sisterly')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Cranky')|(m=='Peppy')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Smug')|(m=='Snooty')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)

    elif(i=='Peppy'):
         for m, n in j.groupby('persB'):

            if((m=='Peppy')|(m=='Jock')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Lazy')|(m=='Snooty')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Smug')|(m=='Sisterly')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)

    elif(i=='Jock'):
        for m, n in j.groupby('persB'):
            if((m=='Peppy')|(m=='Jock')):
                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Lazy')|(m=='Snooty')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Cranky')|(m=='Sisterly')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)

    elif(i=='Snooty'):
        for m, n in j.groupby('persB'):
            if((m=='Normal')|(m=='Cranky')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Peppy')|(m=='Smug')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Lazy')|(m=='Snooty')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)

    elif(i=='Cranky'):
        for m, n in j.groupby('persB'):

            if((m=='Cranky')|(m=='Snooty')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Lazy')|(m=='Sisterly')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Jock')|(m=='Normal')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)


    elif(i=='Smug'):
        for m, n in j.groupby('persB'):

            if((m=='Smug')|(m=='Normal')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Jock')|(m=='Snooty')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Lazy')|(m=='Peppy')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)

    elif(i=='Sisterly'):
         
        for m, n in j.groupby('persB'):

            if((m=='Sisterly')|(m=='Lazy')):

                n['score'] = 3
                pers_list.append(n)
            elif( (m=='Cranky')|(m=='Normal')):
                n['score'] = 2
                pers_list.append(n)
            elif( (m=='Jock')|(m=='Peppy')):
                n['score'] = 1
                pers_list.append(n)
            else:
                n['score'] = 0
                pers_list.append(n)
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:104: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:95: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:101: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
person_score = pd.concat(pers_list,axis=0).reset_index(drop=True)
person_score=person_score.drop_duplicates(keep='first')

# %%
person_score=person_score.drop_duplicates(keep='first')

# %%
person_score.to_csv('/Users/anna/Desktop/Animalcrossing/data/person_score.csv')

# %%
df.loc[df['specious'].isin(['Anteater', 'Alligator'])]='Alligator'

# %%
speA = df['specious']
speB = df['specious']

index = pd.MultiIndex.from_product([speA, speB], names = ["speA", "speB"])

specious_matrix = pd.DataFrame(index = index).reset_index()
specious_list=[]

# %%
for i, j in specious_matrix.groupby('speA'):
    if(i=='Bear'):
        for m, n in j.groupby('speB'):
            if(m=='Cub'):
                
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Bear'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Cub'):
        for m, n in j.groupby('speB'):
            if(m=='Bear'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Cub'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)

    elif(i=='Bull'):
        for m, n in j.groupby('speB'):
            if(m=='Cow'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Bull'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)

    elif(i=='Cow'):
        for m, n in j.groupby('speB'):
            if(m=='Bull'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Cow'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)

    elif(i=='Cat'):
        for m, n in j.groupby('speB'):
            if(m=='Tiger'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Cat'):
                n['score'] = 2
                specious_list.append(n)
            elif((m=='Hamster')|(m=='Mouse') ):
                n['score'] = 0
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Tiger'):
        for m, n in j.groupby('speB'):
            if(m=='Cat'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Tiger'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Dog'):
        for m, n in j.groupby('speB'):
            if(m=='Wolf'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Dog'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
    elif(i=='Wolf'):
        for m, n in j.groupby('speB'):
            if(m=='Dog'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Wolf'):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Sheep'):
                n['score'] = 0
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Goat'):
        for m, n in j.groupby('speB'):
            if(m=='Sheep'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Goat'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Sheep'):
        for m, n in j.groupby('speB'):
            if(m=='Goat'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Sheep'):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Wolf'):
                n['score'] = 0
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Koala'):
        for m, n in j.groupby('speB'):
            if(m=='Kangaroo'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Koala'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Kangaroo'):
        for m, n in j.groupby('speB'):
            if(m=='Koala'):
                n['score'] = 3
                specious_list.append(n)
            elif(m=='Kangaroo'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
     
              
               
    elif(i=='Deer'):
        for m, n in j.groupby('speB'):
            
            if(m=='Horse'):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Deer'):
                n['score'] = 2
                specious_list.append(n)
                
            else:
                n['score'] = 1
                specious_list.append(n)
    elif(i=='Hourse'):
        for m, n in j.groupby('speB'):
            
            if(m=='Deer'):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Hourse'):
                n['score'] = 2
                specious_list.append(n)
                
            else:
                n['score'] = 1
                specious_list.append(n)
    elif(i=='Hamster'):
        for m, n in j.groupby('speB'):
            
            if((m=='Squirrel') | (m=='Mouse') ):
                n['score'] = 2
                specious_list.append(n)
            elif((m=='Cat')):
                n['score'] = 0
                specious_list.append(n)
            elif(m=='Hamster'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
    elif(i=='Mouse'):
        for m, n in j.groupby('speB'):
            
            if((m=='Squirrel') | (m=='Hamster') ):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Mouse'):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Cat'):
                n['score'] = 0
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    elif(i=='Squirrel'):
        for m, n in j.groupby('speB'):
            
            if((m=='Mouse') | (m=='Hamster') ):
                n['score'] = 2
                specious_list.append(n)
            elif(m=='Squirrel'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
                
    
    elif(i=='Gorilla'):
        for m, n in j.groupby('speB'):
            
            if(m=='Dog'):
                n['score'] = 0
                specious_list.append(n)
            elif(m=='Gorilla'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
    elif(i=='Dog'):
        for m, n in j.groupby('speB'):
            
            if((m=='Gorilla')|(m=='Monkey')):
                n['score'] = 0
                specious_list.append(n)
            elif(m=='Dog'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)

    elif(i=='Monkey'):
        for m, n in j.groupby('speB'):
            
            if(m=='Dog'):
                n['score'] = 0
                specious_list.append(n)
            elif(m=='Monkey'):
                n['score'] = 2
                specious_list.append(n)
            else:
                n['score'] = 1
                specious_list.append(n)
    else:
        for m, n in j.groupby('speB'):
            
            if(m==i):
                n['score'] = 2
                specious_list.append(n)

            else:

                n['score'] = 1
                specious_list.append(n)
# Out:
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:271: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:276: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /anaconda3/lib/python3.5/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
spe_score = pd.concat(specious_list,axis=0).reset_index(drop=True)
spe_score=spe_score.drop_duplicates(keep='first')

# %%
spe_score.to_csv('/Users/anna/Desktop/Animalcrossing/data/spe_score.csv')

# %%
spe_score=pd.read_csv('/Users/anna/Desktop/Animalcrossing/data/spe_score.csv')
person_score=pd.read_csv('/Users/anna/Desktop/Animalcrossing/data/person_score.csv')
star_score=pd.read_csv('/Users/anna/Desktop/Animalcrossing/data/star_score.csv')
ani=pd.read_csv('/Users/anna/Desktop/Animalcrossing/data/animals_df.csv')

# %%
del spe_score['Unnamed: 0']
del person_score['Unnamed: 0']
del star_score['Unnamed: 0']
del ani['Unnamed: 0']

# %%
sample = ani[['title','specious','personality','star']]

# %%
sample.shape
# Out:
# (390, 4)

# %%
aniA = sample['title']
aniB = sample['title']

index = pd.MultiIndex.from_product([aniA, aniB], names = ["aniA", "aniB"])

ani_matrix = pd.DataFrame(index = index).reset_index()

# %%
merged_1 = pd.merge(ani_matrix,sample,left_on="aniA",right_on="title")

# %%
merged_2 = pd.merge(merged_1,sample,left_on="aniB",right_on="title")

# %%
del merged_2['title_x']
del merged_2['title_y']

# %%
merged_2.star_x = merged_2.star_x.str.capitalize()
merged_2.star_y = merged_2.star_y.str.capitalize()

# %%
merged_2.head()
# Out:
#       aniA     aniB specious_x personality_x  star_x specious_y personality_y  \
# 0  Agent S  Agent S   Squirrel         Peppy  Cancer   Squirrel         Peppy
# 1    Agnes  Agent S        Pig      Sisterly  Taurus   Squirrel         Peppy
# 2       Al  Agent S    Gorilla          Lazy   Libra   Squirrel         Peppy
# 3  Alfonso  Agent S  Alligator          Lazy  Gemini   Squirrel         Peppy
# 4    Alice  Agent S      Koala        Normal     Leo   Squirrel         Peppy
#
#    star_y
# 0  Cancer
# 1  Cancer
# 2  Cancer
# 3  Cancer
# 4  Cancer

# %%
spe_score.speA = spe_score.speA.apply(lambda x: x.strip(" "))
spe_score.speB = spe_score.speB.apply(lambda x: x.strip(" "))
merged_2.specious_x= merged_2.specious_x.apply(lambda x: x.strip(" "))
merged_2.specious_y = merged_2.specious_y.apply(lambda x: x.strip(" "))

# %%
df_list = []

for i, j in merged_2.iterrows():
    if(i %1000==0):
        print(i/152100)
    
    try:
        specious_x = j['specious_x']
        specious_y = j['specious_y']

        r=spe_score[(spe_score['speA'] == specious_x)&(spe_score['speB'] == specious_y)]

        j['specious_score'] = r['score'].iloc[0]
    
    
    except:
        j['specious_score'] = 1
        
    
    
    star_x = j['star_x']
    star_y = j['star_y']

    
    s=star_score[(star_score['starA'] == star_x)&(star_score['starB'] == star_y)]


    j['star_score'] = s['score'].iloc[0]
   
    
    personality_x = j['personality_x']
    personality_y = j['personality_y']

    
    p=person_score[(person_score['persA'] == personality_x)&(person_score['persB'] == personality_y)]
    j['personality_score'] = p['score'].iloc[0]
    df_list.append(j)
# Out:
# 0.0
# 0.006574621959237344
# 0.013149243918474688
# 0.01972386587771203
# 0.026298487836949377
# 0.03287310979618672
# 0.03944773175542406
# 0.04602235371466141
# 0.05259697567389875
# 0.05917159763313609
# 0.06574621959237344
# 0.07232084155161078
# 0.07889546351084813
# 0.08547008547008547
# 0.09204470742932282
# 0.09861932938856016
# 0.1051939513477975
# 0.11176857330703485
# 0.11834319526627218
# 0.12491781722550953
# 0.13149243918474687
# 0.13806706114398423
# 0.14464168310322156
# 0.15121630506245892
# 0.15779092702169625
# 0.16436554898093358
# 0.17094017094017094
# 0.17751479289940827
# 0.18408941485864563
# 0.19066403681788296
# 0.19723865877712032
# 0.20381328073635765
# 0.210387902695595
# 0.21696252465483234
# 0.2235371466140697
# 0.23011176857330704
# 0.23668639053254437
# 0.24326101249178173
# 0.24983563445101906
# 0.2564102564102564
# 0.26298487836949375
# 0.2695595003287311
# 0.27613412228796846
# 0.28270874424720577
# 0.2892833662064431
# 0.2958579881656805
# ...

# %%
new_df = pd.concat(df_list,axis=1)

# %%
summary = new_df.T

# %%
summary['total_score'] = summary['specious_score'] + summary['star_score'] +summary['personality_score']

# %%
summary.to_csv('/Users/anna/Desktop/Animalcrossing/data/summary.csv')

# %%
summary[summary.aniA=='Marshal']
# Out:
#            aniA      aniB specious_x personality_x star_x      specious_y  \
# 227     Marshal   Agent S   Squirrel          Smug  Libra        Squirrel
# 617     Marshal     Agnes   Squirrel          Smug  Libra             Pig
# 1007    Marshal        Al   Squirrel          Smug  Libra         Gorilla
# 1397    Marshal   Alfonso   Squirrel          Smug  Libra       Alligator
# 1787    Marshal     Alice   Squirrel          Smug  Libra           Koala
# 2177    Marshal      Alli   Squirrel          Smug  Libra       Alligator
# 2567    Marshal    Amelia   Squirrel          Smug  Libra           Eagle
# 2957    Marshal  Anabelle   Squirrel          Smug  Libra        Anteater
# 3347    Marshal   Anchovy   Squirrel          Smug  Libra            Bird
# 3737    Marshal     Angus   Squirrel          Smug  Libra            Bull
# 4127    Marshal  Anicotti   Squirrel          Smug  Libra           Mouse
# 4517    Marshal     Ankha   Squirrel          Smug  Libra             Cat
# ...
